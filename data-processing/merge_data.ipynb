# %%
import pandas as pd
import glob

csv_files = glob.glob("data/2014/*.csv")

# %%
csv_files
# Out:
# ['data/2014/954208240_T_ONTIME_REPORTING 11.csv',
#  'data/2014/954208240_T_ONTIME_REPORTING 10.csv',
#  'data/2014/954208240_T_ONTIME_REPORTING 12.csv',
#  'data/2014/954208240_T_ONTIME_REPORTING 9.csv',
#  'data/2014/954208240_T_ONTIME_REPORTING 8.csv',
#  'data/2014/954208240_T_ONTIME_REPORTING.csv',
#  'data/2014/954208240_T_ONTIME_REPORTING 3.csv',
#  'data/2014/954208240_T_ONTIME_REPORTING 2.csv',
#  'data/2014/954208240_T_ONTIME_REPORTING 6.csv',
#  'data/2014/954208240_T_ONTIME_REPORTING 7.csv',
#  'data/2014/954208240_T_ONTIME_REPORTING 5.csv',
#  'data/2014/954208240_T_ONTIME_REPORTING 4.csv']

# %%
line_num_sum = 0
for i in range(len(csv_files)):
    with open(csv_files[i]) as f:
        line_num = sum(1 for line in f)
        print(line_num)
        line_num_sum += line_num
print(line_num_sum - len(csv_files) + 1)
# Out:
# 491012
# 462055
# 477184
# 507492
# 469490
# 471950
# 503759
# 430603
# 502618
# 499279
# 520881
# 483500
# 5819812

# %%
df = pd.concat((pd.read_csv(f, header = 0) for f in csv_files))
df.to_csv("data/2014.csv")

# %%
data = pd.read_csv("data/2014.csv")
data_top = data.head()
data_top
# Out:
#    Unnamed: 0  YEAR  MONTH  DAY_OF_MONTH  DAY_OF_WEEK     FL_DATE  \
# 0           0  2014     10             1            3  2014-10-01
# 1           1  2014     10             2            4  2014-10-02
# 2           2  2014     10             3            5  2014-10-03
# 3           3  2014     10             4            6  2014-10-04
# 4           4  2014     10             5            7  2014-10-05
#
#   OP_UNIQUE_CARRIER  OP_CARRIER_AIRLINE_ID OP_CARRIER TAIL_NUM  ...  ARR_TIME  \
# 0                AA                  19805         AA   N785AA  ...    1202.0
# 1                AA                  19805         AA   N783AA  ...    1207.0
# 2                AA                  19805         AA   N786AA  ...    1145.0
# 3                AA                  19805         AA   N784AA  ...    1203.0
# 4                AA                  19805         AA   N792AA  ...    1218.0
#
#    ARR_DELAY  ARR_DELAY_NEW  ARR_DEL15 CANCELLED DIVERTED AIR_TIME  FLIGHTS  \
# ...
